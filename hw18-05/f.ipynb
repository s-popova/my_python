# %%
import pandas as pd

url = "https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/football.csv"

football = pd.read_csv(url)
football.head()
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
round(football.Age.mean())
# Out:
# 25

# %%
football.Composure.count()
# Out:
# 12897

# %%
round(football.ShortPassing.std(),3)
# Out:
# 14.74

# %%
football.Wage.sum()
# Out:
# 96954000

# %%
football.Value.min()
# Out:
# 0

# %%
round(football[football.Wage > football.Wage.mean()].SprintSpeed.mean(),2)
# Out:
# 67.57

# %%
round(football[football.Wage < football.Wage.mean()].SprintSpeed.mean(),2)
# Out:
# 62.41

# %%
football[football.Wage == football.Wage.max()].Position
football[football.Nationality == 'Brazil'].Penalties.count()
# Out:
# 423

# %%
round(football[football.HeadingAccuracy > 50].Age.mean(),2)
# Out:
# 25.59

# %%
football[(football.Composure >= (0.9 * football.Composure.max()))&(football.Reactions >= (football.Reactions.max() * 0.9))].Age.min()
# Out:
# 24

# %%
a=football[football.Age==football.Age.max()].Reactions.mean()
b=football[football.Age==football.Age.min()].Reactions.mean()
round(a-b,2)
# Out:
# 22.64

# %%
football[football.Value>=football.Value.mean()].Nationality.max()
# Out:
# 'Zimbabwe'

# %%
a=football[football.Position=='GK'].GKReflexes.max()
b=football[football.Position=='GK'].GKHandling.max()
a=football[football.GKReflexes==a].Wage.mean()
b=football[football.GKHandling==b].Wage.mean()
round(a/b,2)
# Out:
# 2.77

# %%
a=football[football.Aggression==football.Aggression.max()].ShotPower.mean()
b=football[football.Aggression==football.Aggression.min()].ShotPower.mean()

round(a/b,2)
# Out:
# 2.08
